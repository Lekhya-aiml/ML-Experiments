# %%
# import packages
import numpy as np # NumPy is a Python package that stands for ‘Numerical Python’. It is the core library for scientific computing
import pandas as pd # Pandas is used for data manipulation, analysis and cleaning.
import matplotlib.pyplot as plt # powerful plotting library for python that offers a varied spectrum of 1D, 2D, and 3D visualizations.
from IPython.display import display, HTML, display_html # Display the HTML representation of an object.
import seaborn as sns # Seaborn is a data visualization library in Python based on matplotlib

# %%
from pandas import read_csv #  imports a CSV file to DataFrame format.
data = read_csv('heart.csv')# read csv

# %%
data
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
data['Sex'] = data['Sex'].map({'M':1,'F':0})
data['ChestPainType'] = data['ChestPainType'].map({'ATA':1,'TA':0,'NAP':2,'ASY':3})
data['RestingECG'] = data['RestingECG'].map({'Normal':1,'ST':2,'LVH':3})
data['ExerciseAngina'] = data['ExerciseAngina'].map({'Y':1,'N':0})
data['ST_Slope'] = data['ST_Slope'].map({'Up':1,'Flat':2,'Down':3})
data
# Out:
#      Age  Sex  ChestPainType  RestingBP  Cholesterol  FastingBS  RestingECG  \
# 0     40    1              1        140          289          0           1
# 1     49    0              2        160          180          0           1
# 2     37    1              1        130          283          0           2
# 3     48    0              3        138          214          0           1
# 4     54    1              2        150          195          0           1
# ..   ...  ...            ...        ...          ...        ...         ...
# 913   45    1              0        110          264          0           1
# 914   68    1              3        144          193          1           1
# 915   57    1              3        130          131          0           1
# 916   57    0              1        130          236          0           3
# 917   38    1              2        138          175          0           1
#
# ...

# %%
data
# Out:
#      Age  Sex  ChestPainType  RestingBP  Cholesterol  FastingBS  RestingECG  \
# 0     40    1              1        140          289          0           1
# 1     49    0              2        160          180          0           1
# 2     37    1              1        130          283          0           2
# 3     48    0              3        138          214          0           1
# 4     54    1              2        150          195          0           1
# ..   ...  ...            ...        ...          ...        ...         ...
# 913   45    1              0        110          264          0           1
# 914   68    1              3        144          193          1           1
# 915   57    1              3        130          131          0           1
# 916   57    0              1        130          236          0           3
# 917   38    1              2        138          175          0           1
#
# ...

# %%
# !pip install ydata-profiling
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 398.7/398.7 kB 28.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.7/296.7 kB 25.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 94.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 679.7/679.7 kB 43.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.4/105.4 kB 9.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.3/43.3 kB 3.8 MB/s eta 0:00:00
# ...

# %%
import ydata_profiling as yd
profile = yd.ProfileReport(data)
profile.to_file("output.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
# %matplotlib inline

# %%
from autoviz.AutoViz_Class import AutoViz_Class
import pandas as pd

# Instantiate the AutoViz class
AV = AutoViz_Class()

# Generate and display plots
dft = AV.AutoViz(
    filename="",  # No file path because we're using a DataFrame
    sep=",",  # Separator used in the file; irrelevant for DataFrame
    depVar="HeartDisease",  # Dependent variable
    dfte=data,  # DataFrame to analyze
    header=0,  # Header row index
    verbose=2,  # Verbose level for details
    lowess=False,  # Disable lowess smoothing
    chart_format="png",  # Plot format
    max_rows_analyzed=520,  # Maximum rows to analyze
    max_cols_analyzed=20,  # Maximum columns to analyze
    save_plot_dir=None  # Inline plots; no saving
)
# Out:
#     Since nrows is smaller than dataset, loading random sample of 520 rows into pandas...
# Shape of your Data Set loaded: (520, 12)
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
#   Printing up to 30 columns (max) in each category:
#     Numeric Columns : ['Oldpeak']
#     Integer-Categorical Columns: ['Age', 'ChestPainType', 'RestingBP', 'Cholesterol', 'RestingECG', 'MaxHR', 'ST_Slope']
#     String-Categorical Columns: []
#     Factor-Categorical Columns: []
#     String-Boolean Columns: []
#     Numeric-Boolean Columns: ['Sex', 'FastingBS', 'ExerciseAngina']
#     Discrete String Columns: []
#     NLP text Columns: []
#     Date Time Columns: []
#     ID Columns: []
# ...
